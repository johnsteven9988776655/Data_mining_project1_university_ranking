# %%
import pandas as pd  #for data manipulation and analysis (importing library)
import csv #for reading csv files

# %%
#defining class
class University:
    
    def __init__(university, name, country, overall_score, world_rank, year):
        
       # The constructor method initializes a new University object with its attributes.
       # It converts numeric data to the correct types (float, int).
        
        university.name = name
        university.country = country
        university.overall_score = float(overall_score)
        university.world_rank = int(world_rank)
        university.year = int(year)

    def display_info(university):
        
        #This is a method within the class. It provides a clean, formatted way
        #to print the key information for a single university.
        
        print(f"  Name: {university.name} ({university.year})")
        print(f"  Country: {university.country}")
        print(f"  World Rank: {university.world_rank}")
        print(f"  Score: {university.overall_score:.2f}")
        print("-" * 30)

# %%
#load university data
#function definitions

def load_university_data(filepath="cwurData.csv"):
    #A list is created here to store all the University objects we create.
    universities_list = []
    try:
        with open(filepath, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['score']:
                    uni_object = University(
                        name=row['institution'],
                        country=row['country'],
                        overall_score=row['score'],
                        world_rank=row['world_rank'],
                        year=row['year']
                    )
                    universities_list.append(uni_object)
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        
    return universities_list

# %%
#group and rank by country

def group_and_rank_by_country(universities_list):
    grouped_data = {}
    
    for uni in universities_list:
        country = uni.country
        if country not in grouped_data:
            grouped_data[country] = []
        grouped_data[country].append(uni)
        
    for country, unis in grouped_data.items():
        unis.sort(key=lambda u: u.world_rank)
        
    return grouped_data

# %%
#main execution

print(" World University Rankings Analysis ")

# Load data
all_universities = load_university_data()

if all_universities:
    print(f"\nSuccessfully loaded data for {len(all_universities)} university entries across all years.")

    # Filter for 2015
    universities_2015 = []
    for uni in all_universities:
        if uni.year == 2015:
            universities_2015.append(uni)

    print(f"Found {len(universities_2015)} entries for the year 2015.")

    # Group by country
    ranked_by_country_2015 = group_and_rank_by_country(universities_2015)

    # Display top 5 universities for selected countries
    countries_to_display = ["USA", "United Kingdom", "Canada",
                             "Germany", "Japan","France","Switzerland",
                             "Australia","Italy","Netherlands"]

    for country in countries_to_display:
        if country in ranked_by_country_2015:
            print(f"\n--- Top 10 Universities in {country} (2015) ---")
            top_universities = ranked_by_country_2015[country]
            
            for i in range(min(10, len(top_universities))):
                uni = top_universities[i]
                print(f"National Rank: {i+1}")
                uni.display_info()
        else:
            print(f"\n--- No data found for {country} in 2015 ---")
# Out:
#  World University Rankings Analysis
#
# Successfully loaded data for 2200 university entries across all years.
# Found 1000 entries for the year 2015.
#
# --- Top 10 Universities in USA (2015) ---
# National Rank: 1
#   Name: Harvard University (2015)
#   Country: USA
#   World Rank: 1
#   Score: 100.00
# ------------------------------
# National Rank: 2
#   Name: Stanford University (2015)
#   Country: USA
#   World Rank: 2
#   Score: 98.66
# ------------------------------
# National Rank: 3
#   Name: Massachusetts Institute of Technology (2015)
#   Country: USA
#   World Rank: 3
#   Score: 97.54
# ------------------------------
# National Rank: 4
#   Name: Columbia University (2015)
#   Country: USA
#   World Rank: 6
#   Score: 96.14
# ------------------------------
# National Rank: 5
#   Name: University of California, Berkeley (2015)
#   Country: USA
#   World Rank: 7
#   Score: 92.25
# ------------------------------
# National Rank: 6
#   Name: University of Chicago (2015)
#   Country: USA
#   World Rank: 8
#   Score: 90.70
# ------------------------------
# National Rank: 7
#   Name: Princeton University (2015)
#   Country: USA
#   World Rank: 9
#   Score: 89.42
# ------------------------------
# National Rank: 8
#   Name: Cornell University (2015)
#   Country: USA
#   World Rank: 10
#   Score: 86.79
# ------------------------------
# National Rank: 9
#   Name: Yale University (2015)
#   Country: USA
#   World Rank: 11
#   Score: 86.61
# ------------------------------
# National Rank: 10
#   Name: California Institute of Technology (2015)
#   Country: USA
#   World Rank: 12
#   Score: 84.40
# ------------------------------
#
# --- Top 10 Universities in United Kingdom (2015) ---
# National Rank: 1
#   Name: University of Cambridge (2015)
#   Country: United Kingdom
#   World Rank: 4
#   Score: 96.81
# ------------------------------
# National Rank: 2
#   Name: University of Oxford (2015)
#   Country: United Kingdom
#   World Rank: 5
#   Score: 96.46
# ------------------------------
# National Rank: 3
#   Name: University College London (2015)
#   Country: United Kingdom
#   World Rank: 27
#   Score: 62.27
# ------------------------------
# National Rank: 4
#   Name: Imperial College London (2015)
#   Country: United Kingdom
#   World Rank: 35
#   Score: 59.61
# ------------------------------
# National Rank: 5
#   Name: University of Edinburgh (2015)
#   Country: United Kingdom
#   World Rank: 55
#   Score: 54.39
# ------------------------------
# National Rank: 6
#   Name: University of Manchester (2015)
#   Country: United Kingdom
#   World Rank: 67
#   Score: 53.38
# ------------------------------
# National Rank: 7
#   Name: King's College London (2015)
#   Country: United Kingdom
#   World Rank: 94
#   Score: 51.31
# ------------------------------
# National Rank: 8
#   Name: University of Bristol (2015)
#   Country: United Kingdom
#   World Rank: 123
#   Score: 49.59
# ------------------------------
# National Rank: 9
#   Name: University of Glasgow (2015)
#   Country: United Kingdom
#   World Rank: 128
#   Score: 49.45
# ------------------------------
# National Rank: 10
#   Name: University of Nottingham (2015)
#   Country: United Kingdom
#   World Rank: 140
#   Score: 49.02
# ------------------------------
#
# --- Top 10 Universities in Canada (2015) ---
# National Rank: 1
#   Name: University of Toronto (2015)
#   Country: Canada
#   World Rank: 32
#   Score: 60.04
# ------------------------------
# National Rank: 2
#   Name: McGill University (2015)
#   Country: Canada
#   World Rank: 42
#   Score: 56.49
# ------------------------------
# National Rank: 3
#   Name: University of British Columbia (2015)
#   Country: Canada
#   World Rank: 62
#   Score: 53.92
# ------------------------------
# National Rank: 4
#   Name: University of Alberta (2015)
#   Country: Canada
#   World Rank: 107
#   Score: 50.25
# ------------------------------
# National Rank: 5
#   Name: Western University (The University of Western Ontario) (2015)
#   Country: Canada
#   World Rank: 133
#   Score: 49.31
# ------------------------------
# National Rank: 6
#   Name: McMaster University (2015)
#   Country: Canada
#   World Rank: 150
#   Score: 48.74
# ------------------------------
# National Rank: 7
#   Name: University of Montreal (2015)
#   Country: Canada
#   World Rank: 151
#   Score: 48.72
# ------------------------------
# National Rank: 8
#   Name: University of Calgary (2015)
#   Country: Canada
#   World Rank: 167
#   Score: 48.23
# ------------------------------
# National Rank: 9
#   Name: University of Ottawa (2015)
#   Country: Canada
#   World Rank: 193
#   Score: 47.60
# ------------------------------
# National Rank: 10
#   Name: University of Manitoba (2015)
#   Country: Canada
#   World Rank: 222
#   Score: 47.04
# ------------------------------
#
# --- Top 10 Universities in Germany (2015) ---
# National Rank: 1
#   Name: Ruprecht Karl University of Heidelberg (2015)
#   Country: Germany
#   World Rank: 76
#   Score: 52.32
# ------------------------------
# National Rank: 2
#   Name: Ludwig Maximilian University of Munich (2015)
#   Country: Germany
#   World Rank: 79
#   Score: 52.16
# ------------------------------
# National Rank: 3
#   Name: Technical University of Munich (2015)
#   Country: Germany
#   World Rank: 101
#   Score: 50.58
# ------------------------------
# National Rank: 4
#   Name: Free University of Berlin (2015)
#   Country: Germany
#   World Rank: 147
#   Score: 48.78
# ------------------------------
# National Rank: 5
#   Name: Humboldt University of Berlin (2015)
#   Country: Germany
#   World Rank: 153
#   Score: 48.64
# ------------------------------
# National Rank: 6
#   Name: Albert Ludwig University of Freiburg (2015)
#   Country: Germany
#   World Rank: 155
#   Score: 48.57
# ------------------------------
# National Rank: 7
#   Name: University of Tübingen (2015)
#   Country: Germany
#   World Rank: 156
#   Score: 48.56
# ------------------------------
# National Rank: 8
#   Name: University of Bonn (2015)
#   Country: Germany
#   World Rank: 158
#   Score: 48.54
# ------------------------------
# National Rank: 9
#   Name: University of Hamburg (2015)
#   Country: Germany
#   World Rank: 162
#   Score: 48.31
# ------------------------------
# National Rank: 10
#   Name: Goethe University Frankfurt (2015)
#   Country: Germany
#   World Rank: 176
#   Score: 48.01
# ------------------------------
#
# --- Top 10 Universities in Japan (2015) ---
# National Rank: 1
#   Name: University of Tokyo (2015)
#   Country: Japan
#   World Rank: 13
#   Score: 78.23
# ------------------------------
# National Rank: 2
#   Name: Kyoto University (2015)
#   Country: Japan
#   World Rank: 17
#   Score: 68.60
# ------------------------------
# National Rank: 3
#   Name: Keio University (2015)
#   Country: Japan
#   World Rank: 34
#   Score: 59.84
# ------------------------------
# National Rank: 4
#   Name: Waseda University (2015)
#   Country: Japan
#   World Rank: 38
#   Score: 58.17
# ------------------------------
# National Rank: 5
#   Name: Osaka University (2015)
#   Country: Japan
#   World Rank: 45
#   Score: 56.03
# ------------------------------
# National Rank: 6
#   Name: Tohoku University (2015)
#   Country: Japan
#   World Rank: 73
#   Score: 52.57
# ------------------------------
# National Rank: 7
#   Name: Kyushu University (2015)
#   Country: Japan
#   World Rank: 100
#   Score: 50.60
# ------------------------------
# National Rank: 8
#   Name: Tokyo Institute of Technology (2015)
#   Country: Japan
#   World Rank: 109
#   Score: 50.13
# ------------------------------
# National Rank: 9
#   Name: Nagoya University (2015)
#   Country: Japan
#   World Rank: 125
#   Score: 49.57
# ------------------------------
# National Rank: 10
#   Name: Hokkaido University (2015)
#   Country: Japan
#   World Rank: 178
#   Score: 47.97
# ------------------------------
#
# --- Top 10 Universities in France (2015) ---
# National Rank: 1
#   Name: École Polytechnique (2015)
#   Country: France
#   World Rank: 36
#   Score: 59.20
# ------------------------------
# National Rank: 2
#   Name: École normale supérieure - Paris (2015)
#   Country: France
#   World Rank: 37
#   Score: 58.80
# ------------------------------
# National Rank: 3
#   Name: University of Paris-Sud (2015)
#   Country: France
#   World Rank: 58
#   Score: 54.21
# ------------------------------
# National Rank: 4
#   Name: Pierre-and-Marie-Curie University (2015)
#   Country: France
#   World Rank: 63
#   Score: 53.79
# ------------------------------
# National Rank: 5
#   Name: Mines ParisTech (2015)
#   Country: France
#   World Rank: 104
#   Score: 50.34
# ------------------------------
# National Rank: 6
#   Name: Paris Diderot University - Paris 7 (2015)
#   Country: France
#   World Rank: 131
#   Score: 49.33
# ------------------------------
# National Rank: 7
#   Name: University of Strasbourg (2015)
#   Country: France
#   World Rank: 182
#   Score: 47.89
# ------------------------------
# National Rank: 8
#   Name: Joseph Fourier University (2015)
#   Country: France
#   World Rank: 188
#   Score: 47.71
# ------------------------------
# National Rank: 9
#   Name: Aix-Marseille University (2015)
#   Country: France
#   World Rank: 206
#   Score: 47.31
# ------------------------------
# National Rank: 10
#   Name: Claude Bernard University Lyon 1 (2015)
#   Country: France
#   World Rank: 207
#   Score: 47.31
# ------------------------------
#
# --- Top 10 Universities in Switzerland (2015) ---
# National Rank: 1
#   Name: Swiss Federal Institute of Technology in Zurich (2015)
#   Country: Switzerland
#   World Rank: 20
#   Score: 66.93
# ------------------------------
# National Rank: 2
#   Name: Swiss Federal Institute of Technology in Lausanne (2015)
#   Country: Switzerland
#   World Rank: 91
#   Score: 51.47
# ------------------------------
# National Rank: 3
#   Name: University of Geneva (2015)
#   Country: Switzerland
#   World Rank: 92
#   Score: 51.46
# ------------------------------
# National Rank: 4
#   Name: University of Zurich (2015)
#   Country: Switzerland
#   World Rank: 96
#   Score: 51.14
# ------------------------------
# National Rank: 5
#   Name: University of Basel (2015)
#   Country: Switzerland
#   World Rank: 160
#   Score: 48.48
# ------------------------------
# National Rank: 6
#   Name: University of Lausanne (2015)
#   Country: Switzerland
#   World Rank: 186
#   Score: 47.73
# ------------------------------
# National Rank: 7
#   Name: University of Bern (2015)
#   Country: Switzerland
#   World Rank: 200
#   Score: 47.49
# ------------------------------
# National Rank: 8
#   Name: University of Fribourg (2015)
#   Country: Switzerland
#   World Rank: 573
#   Score: 44.58
# ------------------------------
# National Rank: 9
#   Name: University of Neuchâtel (2015)
#   Country: Switzerland
#   World Rank: 758
#   Score: 44.29
# ------------------------------
#
# --- Top 10 Universities in Australia (2015) ---
# National Rank: 1
#   Name: University of Sydney (2015)
#   Country: Australia
#   World Rank: 88
#   Score: 51.61
# ------------------------------
# National Rank: 2
#   Name: University of Melbourne (2015)
#   Country: Australia
#   World Rank: 93
#   Score: 51.34
# ------------------------------
# National Rank: 3
#   Name: University of Queensland (2015)
#   Country: Australia
#   World Rank: 103
#   Score: 50.40
# ------------------------------
# National Rank: 4
#   Name: University of New South Wales (2015)
#   Country: Australia
#   World Rank: 130
#   Score: 49.33
# ------------------------------
# National Rank: 5
#   Name: Monash University (2015)
#   Country: Australia
#   World Rank: 145
#   Score: 48.91
# ------------------------------
# National Rank: 6
#   Name: Australian National University (2015)
#   Country: Australia
#   World Rank: 179
#   Score: 47.97
# ------------------------------
# National Rank: 7
#   Name: University of Western Australia (2015)
#   Country: Australia
#   World Rank: 216
#   Score: 47.10
# ------------------------------
# National Rank: 8
#   Name: University of Adelaide (2015)
#   Country: Australia
#   World Rank: 335
#   Score: 45.58
# ------------------------------
# National Rank: 9
#   Name: Macquarie University (2015)
#   Country: Australia
#   World Rank: 449
#   Score: 44.96
# ------------------------------
# National Rank: 10
#   Name: University of Wollongong (2015)
#   Country: Australia
#   World Rank: 467
#   Score: 44.88
# ------------------------------
#
# --- Top 10 Universities in Italy (2015) ---
# National Rank: 1
#   Name: Sapienza University of Rome (2015)
#   Country: Italy
#   World Rank: 112
#   Score: 49.97
# ------------------------------
# National Rank: 2
#   Name: University of Padua (2015)
#   Country: Italy
#   World Rank: 169
#   Score: 48.17
# ------------------------------
# National Rank: 3
#   Name: University of Milan (2015)
#   Country: Italy
#   World Rank: 172
#   Score: 48.07
# ------------------------------
# National Rank: 4
#   Name: University of Bologna (2015)
#   Country: Italy
#   World Rank: 208
#   Score: 47.28
# ------------------------------
# National Rank: 5
#   Name: University of Turin (2015)
#   Country: Italy
#   World Rank: 221
#   Score: 47.04
# ------------------------------
# National Rank: 6
#   Name: University of Florence (2015)
#   Country: Italy
#   World Rank: 247
#   Score: 46.58
# ------------------------------
# National Rank: 7
#   Name: University of Naples Federico II (2015)
#   Country: Italy
#   World Rank: 268
#   Score: 46.36
# ------------------------------
# National Rank: 8
#   Name: University of Pisa (2015)
#   Country: Italy
#   World Rank: 295
#   Score: 46.03
# ------------------------------
# National Rank: 9
#   Name: University of Rome Tor Vergata (2015)
#   Country: Italy
#   World Rank: 317
#   Score: 45.79
# ------------------------------
# National Rank: 10
#   Name: University of Pavia (2015)
#   Country: Italy
#   World Rank: 327
#   Score: 45.64
# ------------------------------
#
# --- Top 10 Universities in Netherlands (2015) ---
# National Rank: 1
#   Name: Erasmus University Rotterdam (2015)
#   Country: Netherlands
#   World Rank: 85
#   Score: 51.78
# ------------------------------
# National Rank: 2
#   Name: Utrecht University (2015)
#   Country: Netherlands
#   World Rank: 87
#   Score: 51.74
# ------------------------------
# National Rank: 3
#   Name: Leiden University (2015)
#   Country: Netherlands
#   World Rank: 108
#   Score: 50.17
# ------------------------------
# National Rank: 4
#   Name: University of Groningen (2015)
#   Country: Netherlands
#   World Rank: 110
#   Score: 50.10
# ------------------------------
# National Rank: 5
#   Name: University of Amsterdam (2015)
#   Country: Netherlands
#   World Rank: 114
#   Score: 49.83
# ------------------------------
# National Rank: 6
#   Name: VU University Amsterdam (2015)
#   Country: Netherlands
#   World Rank: 129
#   Score: 49.44
# ------------------------------
# National Rank: 7
#   Name: Radboud University Nijmegen (2015)
#   Country: Netherlands
#   World Rank: 134
#   Score: 49.30
# ------------------------------
# National Rank: 8
#   Name: Maastricht University (2015)
#   Country: Netherlands
#   World Rank: 225
#   Score: 47.00
# ------------------------------
# National Rank: 9
#   Name: Delft University of Technology (2015)
#   Country: Netherlands
#   World Rank: 255
#   Score: 46.46
# ------------------------------
# National Rank: 10
#   Name: Wageningen University and Research Centre (2015)
#   Country: Netherlands
#   World Rank: 276
#   Score: 46.26
# ------------------------------
